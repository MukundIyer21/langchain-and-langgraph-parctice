# %%
from langchain_community.tools import WikipediaQueryRun,ArxivQueryRun
from langchain_community.utilities import WikipediaAPIWrapper,ArxivAPIWrapper
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage,AIMessage
import os   
import dotenv


from typing import TypedDict, Annotated
from langgraph.graph import StateGraph, END, START
from langgraph.types import Send
from langchain_core.messages import HumanMessage, SystemMessage
import operator

# %%
dotenv.load_dotenv()
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_classic.agents import initialize_agent,AgentType
llm = ChatGroq(model = "llama-3.3-70b-versatile",verbose=True,max_tokens=500,api_key=GROQ_API_KEY)

# %%
class OverallState(TypedDict):
    task: str
    subtasks: list[str]
    results: Annotated[list[str], operator.add]
    final_output: str

# %%
class WorkerState(TypedDict):
    subtask: str
    result: str

# %%
def orchestrator(state: OverallState):
    task = state["task"]
    
    messages = [
        SystemMessage(content="You are an orchestrator. Break down the task into 3 independent subtasks that can be done in parallel."),
        HumanMessage(content=f"Break down this task: {task}\n\nReturn ONLY a numbered list of 3 subtasks, nothing else.")
    ]
    response = llm.invoke(messages)
    
    subtasks = [line.strip() for line in response.content.split('\n') if line.strip() and any(char.isdigit() for char in line[:3])]
    subtasks = [task.split('.', 1)[1].strip() if '.' in task else task for task in subtasks]
    
    return {"subtasks": subtasks}

# %%
def continue_to_workers(state: OverallState):
    return [Send("worker", {"subtask": task}) for task in state["subtasks"]]


def worker(state: WorkerState):
    subtask = state["subtask"]
    
    messages = [
        SystemMessage(content="You are a specialized worker. Complete the given subtask thoroughly."),
        HumanMessage(content=f"Complete this subtask: {subtask}")
    ]
    response = llm.invoke(messages)
    
    return {"results": [f"Subtask: {subtask}\nResult: {response.content}"]}

# %%
def aggregator(state: OverallState):
    results = state["results"]
    
    combined_results = "\n\n".join(results)
    
    messages = [
        SystemMessage(content="You are an aggregator. Combine the results from all workers into a cohesive final output."),
        HumanMessage(content=f"Original task: {state['task']}\n\nWorker results:\n{combined_results}\n\nProvide a final summary.")
    ]
    response = llm.invoke(messages)
    
    return {"final_output": response.content}

# %%
def create_orchestrator_workflow():
    workflow = StateGraph(OverallState)
    
    workflow.add_node("orchestrator", orchestrator)
    workflow.add_node("worker", worker)
    workflow.add_node("aggregator", aggregator)
    
    workflow.add_edge(START, "orchestrator")
    workflow.add_conditional_edges("orchestrator", continue_to_workers, ["worker"])
    workflow.add_edge("worker", "aggregator")
    workflow.add_edge("aggregator", END)
    
    return workflow.compile()

# %%
app = create_orchestrator_workflow()

initial_state = {
    "task": "Plan a 3-day trip to Tokyo including food, attractions, and accommodation",
    "subtasks": [],
    "results": [],
    "final_output": ""
}

# %%
# Just one call
final_state = app.invoke(initial_state)

# Access everything from final_state
print(final_state["subtasks"])
print(final_state["results"])
print(final_state["final_output"])
# Out:
# ['Research and book accommodation options in Tokyo for the 3-day trip', 'Create an itinerary of top attractions and experiences to visit in Tokyo', 'Plan a food itinerary, including restaurants, cafes, and street food to try during the trip']
# ["Subtask: Research and book accommodation options in Tokyo for the 3-day trip\nResult: **Researching Accommodation Options in Tokyo**\n\nTokyo offers a wide range of accommodation options to suit different budgets and preferences. Here are some options to consider for the 3-day trip:\n\n**Luxury Hotels**\n\n1. **Park Hyatt Tokyo**: Located in the heart of Shinjuku, this 5-star hotel offers stunning views of the city and luxurious amenities. (Approx. $500 per night)\n2. **The Ritz-Carlton, Tokyo**: Situated in the Roppongi district, this hotel features elegant rooms and a world-class spa. (Approx. $450 per night)\n3. **Four Seasons Hotel Tokyo at Marunouchi**: This 5-star hotel is located in the financial district and offers sleek, modern rooms and exceptional service. (Approx. $400 per night)\n\n**Mid-Range Hotels**\n\n1. **Hotel Gajoen Tokyo**: A unique hotel featuring traditional Japanese architecture and beautiful gardens. (Approx. $200 per night)\n2. **Remm Akihabara Hotel**: A modern hotel located in the heart of Akihabara, with easy access to Tokyo's electronics and anime districts. (Approx. $150 per night)\n3. **Hotel Niwa Tokyo**: A cozy hotel with a traditional Japanese design, located in a quiet area near the Imperial Palace. (Approx. $120 per night)\n\n**Budget-Friendly Options**\n\n1. **Nui.Tokyo Central Hostel**: A social hostel with dormitory and private rooms, located in the Shinjuku district. (Approx. $30 per night)\n2. **Sakura Hotel Ikebukuro**: A budget-friendly hotel with simple rooms and a convenient location near Ikebukuro Station. (Approx. $80 per night)\n3. **Tokyo Central Inn**: A basic hotel with affordable prices and a central location. (Approx. $60 per night)\n\n**Booking Accommodation**\n\nBased on the research, I recommend booking the **Hotel Gajoen Tokyo** for the 3-day trip. This hotel offers a unique and traditional Japanese experience, with beautiful gardens and a convenient location.\n\n**Booking Details**\n\n* Dates: [Insert dates]\n* Room Type: Deluxe Room\n* Rate: Approx. $200 per night\n* Total Cost: Approx. $600 for 3 nights\n* Booking Platform: Booking.com or the hotel's official website\n\nPlease note that prices may vary depending on the time of year and", "Subtask: Create an itinerary of top attractions and experiences to visit in Tokyo\nResult: **Tokyo Itinerary: Top Attractions and Experiences**\n\nTokyo, the vibrant capital of Japan, is a city that seamlessly blends traditional and modern culture. From ancient temples and shrines to cutting-edge technology and innovative cuisine, Tokyo has something to offer for every interest and traveler. Here's a suggested itinerary to help you experience the best of Tokyo:\n\n**Day 1: Traditional Tokyo**\n\n1. **Meiji Shrine** (9:00 am - 10:00 am): Dedicated to the deified spirits of Emperor Meiji and his wife, Empress Shoken, this shrine is a serene escape from the city's hustle and bustle.\n2. **Yoyogi Park** (10:30 am - 12:00 pm): This popular park is famous for its cherry blossom viewing in the spring and is a great place to people-watch and enjoy the scenery.\n3. **Shibuya Crossing** (1:00 pm - 2:30 pm): Experience the busiest intersection in the world and take a walk around the trendy Shibuya area.\n4. **Asakusa** (3:00 pm - 5:00 pm): Visit Senso-ji Temple, one of the oldest and most iconic temples in Japan, and explore the nearby Nakamise Shopping Street.\n\n**Day 2: Modern Tokyo**\n\n1. **Tokyo Skytree** (9:00 am - 10:30 am): At 634 meters tall, Tokyo Skytree offers breathtaking views of the city from its observation decks.\n2. **Akihabara** (11:00 am - 1:00 pm): Explore the electronic and anime hub of Tokyo, where you can find everything from gadgets to manga and video games.\n3. **Harajuku** (2:00 pm - 4:00 pm): Take a stroll down Takeshita Street, known for its unique and eclectic fashion, and grab a snack at one of the many crepe or cotton candy shops.\n4. **Shinjuku Gyoen National Garden** (5:00 pm - 6:30 pm): Relax in this beaut ...
# **3-Day Trip to Tokyo: Final Itinerary**
#
# This 3-day trip to Tokyo offers a unique blend of traditional and modern experiences, with a focus on food, attractions, and accommodation. Below is a summary of the planned trip:
#
# **Accommodation:**
# The recommended accommodation for this trip is **Hotel Gajoen Tokyo**, a unique hotel featuring traditional Japanese architecture and beautiful gardens. The hotel is located in a convenient area, with easy access to Tokyo's main attractions.
#
# **Itinerary:**
#
# * **Day 1: Traditional Tokyo**
# 	+ Visit Meiji Shrine and Yoyogi Park
# 	+ Experience Shibuya Crossing and explore the trendy Shibuya area
# 	+ Visit Asakusa and explore Senso-ji Temple and Nakamise Shopping Street
# * **Day 2: Modern Tokyo**
# 	+ Visit Tokyo Skytree for breathtaking views of the city
# 	+ Explore Akihabara, the electronic and anime hub of Tokyo
# 	+ Take a stroll down Takeshita Street in Harajuku and grab a snack at one of the many crepe or cotton candy shops
# 	+ Relax in Shinjuku Gyoen National Garden
# * **Day 3: Food and Entertainment**
# 	+ Visit Tsukiji Outer Market for a fascinating glimpse into Tokyo's seafood culture
# 	+ Explore the city's food scene, including restaurants, cafes, and street food
#
# **Food Itinerary:**
# The food itinerary includes a variety of traditional Japanese cuisine, modern takes on classic dishes, and international flavors. Some recommended restaurants and cafes include:
#
# * **Café Belle Époque** for a traditional breakfast
# * **Street Food Market** for a variety of local street food
# * **Restaurant Le Coeur** for modern takes on traditional cuisine
# * **The Daily Grind** for specialty coffee and breakfast sandwiches
# * **Food Truck Park** for a range of international cuisine
# * **The Sweet Spot** for delicious baked goods and desserts
# * **The Fisherman's Wharf** for fresh seafood
# * **The International Café** for traditional breakfast dishes from around the world
# * **The Curry House** for authentic, flavorful curries
# * **The Sushi Bar** for modern Japanese cuisine with a focus on fresh, sustainable ingredients
#
# **Budget Breakdown:**
#
# * Accommodation: Approx. $600 for 3 nights at Hotel Gajoen Tokyo
# * Food and drink: Approx. $500 for meals and snacks throughout
